# %% [markdown]
# # ECG data exploration
# Notebook này chỉ dùng để quan sát dữ liệu **train**. Không dùng test set để exploration/tuning.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.data.loader import load_dataframe, dataframe_to_xy
from src.evaluation.plots import plot_class_distribution, plot_mean_waveform_by_class
df = load_dataframe(ROOT / 'data/splits/train.csv')
X, y = dataframe_to_xy(df)
X.shape, y.shape

# %%
df[['finalLabel','original_index','original_len','generated_window_id','new_len']].describe(include='all')

# %%
import matplotlib.pyplot as plt
for label in [0, 1]:
    plt.plot(X[y == label].mean(axis=0), label=f'class {label}')
plt.legend(); plt.title('Mean train waveform by class'); plt.show()
